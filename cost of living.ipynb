# %% [markdown]
# ## LOADING DATA

# %%
import matplotlib.pyplot as plt

# %%
from pandas.plotting import scatter_matrix

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import pandas as pd

# %%
df= pd.read_excel('cost of living.xlsx')

# %%
df.head()
# Out:
#    Rank      Country  Cost of Living Index  Rent Index  \
# 0     1  Switzerland                 101.1        46.5
# 1     2      Bahamas                  85.0        36.7
# 2     3      Iceland                  83.0        39.2
# 3     4    Singapore                  76.7        67.2
# 4     5     Barbados                  76.6        19.0
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            74.9            109.1                    97.0
# 1                            61.8             81.6                    83.3
# 2                            62.0             88.4                    86.8
# 3                            72.1             74.6                    50.4
# 4                            48.9             80.8                    69.4
#
#    Local Purchasing Power Index
# 0                         158.7
# 1                          54.6
# 2                         120.3
# 3                         111.1
# ...

# %% [markdown]
# ### DATA INSPECTION

# %%
# head,tail,shape,information,columns,check missing values,checking statistical summary ie describe

# %%
df.tail()
# Out:
#      Rank     Country  Cost of Living Index  Rent Index  \
# 116   117  Bangladesh                  22.5         2.4
# 117   118       India                  21.2         5.6
# 118   119       Egypt                  21.0         3.7
# 119   120       Libya                  20.4         4.3
# 120   121    Pakistan                  18.8         2.8
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 116                            12.8             25.7                    12.8
# 117                            13.7             23.8                    15.1
# 118                            12.7             21.2                    16.2
# 119                            12.7             22.2                    15.2
# 120                            11.1             17.5                    12.9
#
#      Local Purchasing Power Index
# 116                          33.1
# 117                          82.6
# 118                          20.0
# ...

# %%
df.shape
# Out:
# (121, 8)

# %%
df.describe()
# Out:
#              Rank  Cost of Living Index  Rent Index  \
# count  121.000000            121.000000  121.000000
# mean    61.000000             43.555372   16.052893
# std     35.073732             16.147574   11.412267
# min      1.000000             18.800000    2.400000
# 25%     31.000000             30.200000    8.500000
# 50%     61.000000             39.500000   12.400000
# 75%     91.000000             52.800000   20.100000
# max    121.000000            101.100000   67.200000
#
#        Cost of Living Plus Rent Index  Groceries Index  \
# count                      121.000000       121.000000
# mean                        30.357851        44.228926
# std                         13.263721        17.055109
# min                         11.100000        17.500000
# 25%                         19.800000        31.600000
# 50%                         27.000000        40.500000
# 75%                         37.000000        53.700000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            121 non-null    int64
#  1   Country                         121 non-null    object
#  2   Cost of Living Index            121 non-null    float64
#  3   Rent Index                      121 non-null    float64
#  4   Cost of Living Plus Rent Index  121 non-null    float64
#  5   Groceries Index                 121 non-null    float64
#  6   Restaurant Price Index          121 non-null    float64
#  7   Local Purchasing Power Index    121 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.7+ KB

# %%
df.isnull().sum()
# Out:
# Rank                              0
# Country                           0
# Cost of Living Index              0
# Rent Index                        0
# Cost of Living Plus Rent Index    0
# Groceries Index                   0
# Restaurant Price Index            0
# Local Purchasing Power Index      0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Rank, Country, Cost of Living Index, Rent Index, Cost of Living Plus Rent Index, Groceries Index, Restaurant Price Index, Local Purchasing Power Index]
# Index: []

# %% [markdown]
# ## DATA CLEANING

# %%
## missing values,duplicates,outliers,data types,

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 116    False
# 117    False
# 118    False
# 119    False
# 120    False
# Length: 121, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Country, Cost of Living Index, Rent Index, Cost of Living Plus Rent Index, Groceries Index, Restaurant Price Index, Local Purchasing Power Index]
# Index: []

# %% [markdown]
# ## ANALYZING DATA

# %%
# GROUPING DATA,GETTING AGGREGATION

# %%
data=df.set_index(["Rank"])

# %%
data
# Out:
#           Country  Cost of Living Index  Rent Index  \
# Rank
# 1     Switzerland                 101.1        46.5
# 2         Bahamas                  85.0        36.7
# 3         Iceland                  83.0        39.2
# 4       Singapore                  76.7        67.2
# 5        Barbados                  76.6        19.0
# ...           ...                   ...         ...
# 117    Bangladesh                  22.5         2.4
# 118         India                  21.2         5.6
# 119         Egypt                  21.0         3.7
# 120         Libya                  20.4         4.3
# 121      Pakistan                  18.8         2.8
#
#       Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# Rank
# 1                               74.9            109.1                    97.0
# 2                               61.8             81.6                    83.3
# 3                               62.0             88.4                    86.8
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Cost of Living Index', 'Rent Index',
#        'Cost of Living Plus Rent Index', 'Groceries Index',
#        'Restaurant Price Index', 'Local Purchasing Power Index'],
#       dtype='object')

# %%
data = data.rename(columns={
    'Cost of Living Index': 'Cost of Living',
    'Rent Index': 'Rent',
    'Cost of Living Plus Rent Index': 'Sum of Rent and COL',
    'Groceries Index': 'Groceries',
    'Restaurant Price Index': 'Restaurant Price',
    'Local Purchasing Power Index': 'Local Purchasing Power',
    
})

# %%
data.head()
# Out:
#           Country  Cost of Living  Rent  Sum of Rent and COL  Groceries  \
# Rank
# 1     Switzerland           101.1  46.5                 74.9      109.1
# 2         Bahamas            85.0  36.7                 61.8       81.6
# 3         Iceland            83.0  39.2                 62.0       88.4
# 4       Singapore            76.7  67.2                 72.1       74.6
# 5        Barbados            76.6  19.0                 48.9       80.8
#
#       Restaurant Price  Local Purchasing Power
# Rank
# 1                 97.0                   158.7
# 2                 83.3                    54.6
# 3                 86.8                   120.3
# 4                 50.4                   111.1
# 5                 69.4                    43.5

# %%
data=data.rename(columns={"Sum of Rent and COL":"Rent and COL"})

# %%
data.head()
# Out:
#           Country  Cost of Living  Rent  Rent and COL  Groceries  \
# Rank
# 1     Switzerland           101.1  46.5          74.9      109.1
# 2         Bahamas            85.0  36.7          61.8       81.6
# 3         Iceland            83.0  39.2          62.0       88.4
# 4       Singapore            76.7  67.2          72.1       74.6
# 5        Barbados            76.6  19.0          48.9       80.8
#
#       Restaurant Price  Local Purchasing Power
# Rank
# 1                 97.0                   158.7
# 2                 83.3                    54.6
# 3                 86.8                   120.3
# 4                 50.4                   111.1
# 5                 69.4                    43.5

# %%
data.reset_index().inplace=True
data.head()
# Out:
#           Country  Cost of Living  Rent  Rent and COL  Groceries  \
# Rank
# 1     Switzerland           101.1  46.5          74.9      109.1
# 2         Bahamas            85.0  36.7          61.8       81.6
# 3         Iceland            83.0  39.2          62.0       88.4
# 4       Singapore            76.7  67.2          72.1       74.6
# 5        Barbados            76.6  19.0          48.9       80.8
#
#       Restaurant Price  Local Purchasing Power
# Rank
# 1                 97.0                   158.7
# 2                 83.3                    54.6
# 3                 86.8                   120.3
# 4                 50.4                   111.1
# 5                 69.4                    43.5

# %%
data.columns
# Out:
# Index(['Country', 'Cost of Living', 'Rent', 'Rent and COL', 'Groceries',
#        'Restaurant Price', 'Local Purchasing Power'],
#       dtype='object')

# %%
data.head()
# Out:
#           Country  Cost of Living  Rent  Rent and COL  Groceries  \
# Rank
# 1     Switzerland           101.1  46.5          74.9      109.1
# 2         Bahamas            85.0  36.7          61.8       81.6
# 3         Iceland            83.0  39.2          62.0       88.4
# 4       Singapore            76.7  67.2          72.1       74.6
# 5        Barbados            76.6  19.0          48.9       80.8
#
#       Restaurant Price  Local Purchasing Power
# Rank
# 1                 97.0                   158.7
# 2                 83.3                    54.6
# 3                 86.8                   120.3
# 4                 50.4                   111.1
# 5                 69.4                    43.5

# %%
data.reset_index()
# Out:
#      Rank      Country  Cost of Living  Rent  Rent and COL  Groceries  \
# 0       1  Switzerland           101.1  46.5          74.9      109.1
# 1       2      Bahamas            85.0  36.7          61.8       81.6
# 2       3      Iceland            83.0  39.2          62.0       88.4
# 3       4    Singapore            76.7  67.2          72.1       74.6
# 4       5     Barbados            76.6  19.0          48.9       80.8
# ..    ...          ...             ...   ...           ...        ...
# 116   117   Bangladesh            22.5   2.4          12.8       25.7
# 117   118        India            21.2   5.6          13.7       23.8
# 118   119        Egypt            21.0   3.7          12.7       21.2
# 119   120        Libya            20.4   4.3          12.7       22.2
# 120   121     Pakistan            18.8   2.8          11.1       17.5
#
#      Restaurant Price  Local Purchasing Power
# 0                97.0                   158.7
# ...

# %%
data.head()
# Out:
#           Country  Cost of Living  Rent  Rent and COL  Groceries  \
# Rank
# 1     Switzerland           101.1  46.5          74.9      109.1
# 2         Bahamas            85.0  36.7          61.8       81.6
# 3         Iceland            83.0  39.2          62.0       88.4
# 4       Singapore            76.7  67.2          72.1       74.6
# 5        Barbados            76.6  19.0          48.9       80.8
#
#       Restaurant Price  Local Purchasing Power
# Rank
# 1                 97.0                   158.7
# 2                 83.3                    54.6
# 3                 86.8                   120.3
# 4                 50.4                   111.1
# 5                 69.4                    43.5

# %%
data= data.set_index(["Rent","Country"])
data.head()
# Out:
#                   Cost of Living  Sum of Rent and COL  Groceries  \
# Rent Country
# 46.5 Switzerland           101.1                 74.9      109.1
# 36.7 Bahamas                85.0                 61.8       81.6
# 39.2 Iceland                83.0                 62.0       88.4
# 67.2 Singapore              76.7                 72.1       74.6
# 19.0 Barbados               76.6                 48.9       80.8
#
#                   Restaurant Price  Local Purchasing Power
# Rent Country
# 46.5 Switzerland              97.0                   158.7
# 36.7 Bahamas                  83.3                    54.6
# 39.2 Iceland                  86.8                   120.3
# 67.2 Singapore                50.4                   111.1
# 19.0 Barbados                 69.4                    43.5

# %%
merged=pd.merge(data,df,on= 'Country', how='left')

# %%
merged.head()
# Out:
#        Country  Cost of Living_x  Rent and COL  Groceries_x  \
# 0  Switzerland             101.1          74.9        109.1
# 1      Bahamas              85.0          61.8         81.6
# 2      Iceland              83.0          62.0         88.4
# 3    Singapore              76.7          72.1         74.6
# 4     Barbados              76.6          48.9         80.8
#
#    Restaurant Price_x  Local Purchasing Power_x  Rank  Cost of Living_y  Rent  \
# 0                97.0                     158.7     1             101.1  46.5
# 1                83.3                      54.6     2              85.0  36.7
# 2                86.8                     120.3     3              83.0  39.2
# 3                50.4                     111.1     4              76.7  67.2
# 4                69.4                      43.5     5              76.6  19.0
#
#    Sum of Rent and COL  Groceries_y  Restaurant Price_y  \
# 0                 74.9        109.1                97.0
# ...

# %%
merged_df.head()
# Out:
#        Country  Cost of Living_x  Rent and COL  Groceries_x  \
# 0  Switzerland             101.1          74.9        109.1
# 1      Bahamas              85.0          61.8         81.6
# 2      Iceland              83.0          62.0         88.4
# 3    Singapore              76.7          72.1         74.6
# 4     Barbados              76.6          48.9         80.8
#
#    Restaurant Price_x  Local Purchasing Power_x  Rank  Cost of Living_y  Rent  \
# 0                97.0                     158.7     1             101.1  46.5
# 1                83.3                      54.6     2              85.0  36.7
# 2                86.8                     120.3     3              83.0  39.2
# 3                50.4                     111.1     4              76.7  67.2
# 4                69.4                      43.5     5              76.6  19.0
#
#    Sum of Rent and COL  Groceries_y  Restaurant Price_y  \
# 0                 74.9        109.1                97.0
# ...

# %%
data.head()
# Out:
#                   Cost of Living  Rent and COL  Groceries  Restaurant Price  \
# Rent Country
# 46.5 Switzerland           101.1          74.9      109.1              97.0
# 36.7 Bahamas                85.0          61.8       81.6              83.3
# 39.2 Iceland                83.0          62.0       88.4              86.8
# 67.2 Singapore              76.7          72.1       74.6              50.4
# 19.0 Barbados               76.6          48.9       80.8              69.4
#
#                   Local Purchasing Power
# Rent Country
# 46.5 Switzerland                   158.7
# 36.7 Bahamas                        54.6
# 39.2 Iceland                       120.3
# 67.2 Singapore                     111.1
# 19.0 Barbados                       43.5

# %%
pivot_table = data.pivot_table(columns='Country',values='Groceries',aggfunc='sum')

# %%
pivot_table
# Out:
# Country    Albania  Algeria  Argentina  Armenia  Australia  Austria  \
# Groceries     42.0     36.8       29.7     36.0       77.3     66.4
#
# Country    Azerbaijan  Bahamas  Bahrain  Bangladesh  ...  Uganda  Ukraine  \
# Groceries        29.0     81.6     46.9        25.7  ...    29.3     25.4
#
# Country    United Arab Emirates  United Kingdom  United States  Uruguay  \
# Groceries                  45.3            56.9           75.0     52.1
#
# Country    Uzbekistan  Venezuela  Vietnam  Zimbabwe
# Groceries        28.4       39.5     33.9      35.5
#
# [1 rows x 121 columns]

# %%
pivot_table_transposed = pivot_table.T

# %%
pivot_table_transposed
# Out:
#             Groceries
# Country
# Albania          42.0
# Algeria          36.8
# Argentina        29.7
# Armenia          36.0
# Australia        77.3
# ...               ...
# Uruguay          52.1
# Uzbekistan       28.4
# Venezuela        39.5
# Vietnam          33.9
# Zimbabwe         35.5
#
# [121 rows x 1 columns]

# %%
data.index= data.index.to_flat_index()
data.head()
# Out:
#                      Cost of Living  Sum of Rent and COL  Groceries  \
# (46.5, Switzerland)           101.1                 74.9      109.1
# (36.7, Bahamas)                85.0                 61.8       81.6
# (39.2, Iceland)                83.0                 62.0       88.4
# (67.2, Singapore)              76.7                 72.1       74.6
# (19.0, Barbados)               76.6                 48.9       80.8
#
#                      Restaurant Price  Local Purchasing Power
# (46.5, Switzerland)              97.0                   158.7
# (36.7, Bahamas)                  83.3                    54.6
# (39.2, Iceland)                  86.8                   120.3
# (67.2, Singapore)                50.4                   111.1
# (19.0, Barbados)                 69.4                    43.5

# %%
data.head()
# Out:
#                      Cost of Living  Sum of Rent and COL  Groceries  \
# (46.5, Switzerland)           101.1                 74.9      109.1
# (36.7, Bahamas)                85.0                 61.8       81.6
# (39.2, Iceland)                83.0                 62.0       88.4
# (67.2, Singapore)              76.7                 72.1       74.6
# (19.0, Barbados)               76.6                 48.9       80.8
#
#                      Restaurant Price  Local Purchasing Power
# (46.5, Switzerland)              97.0                   158.7
# (36.7, Bahamas)                  83.3                    54.6
# (39.2, Iceland)                  86.8                   120.3
# (67.2, Singapore)                50.4                   111.1
# (19.0, Barbados)                 69.4                    43.5

# %%
data.sort_index(level='Country',ascending=False)
# Out:
#           Country  Cost of Living  Rent  Sum of Rent and COL  Groceries  \
# Rank
# 121      Pakistan            18.8   2.8                 11.1       17.5
# 120         Libya            20.4   4.3                 12.7       22.2
# 119         Egypt            21.0   3.7                 12.7       21.2
# 118         India            21.2   5.6                 13.7       23.8
# 117    Bangladesh            22.5   2.4                 12.8       25.7
# ...           ...             ...   ...                  ...        ...
# 5        Barbados            76.6  19.0                 48.9       80.8
# 4       Singapore            76.7  67.2                 72.1       74.6
# 3         Iceland            83.0  39.2                 62.0       88.4
# 2         Bahamas            85.0  36.7                 61.8       81.6
# 1     Switzerland           101.1  46.5                 74.9      109.1
#
#       Restaurant Price  Local Purchasing Power
# Rank
# ...

# %%
#data.reset_index(drop=True, inplace=True)

# %%
data.head()
# Out:
#           Country  Cost of Living  Rent  Sum of Rent and COL  Groceries  \
# Rank
# 1     Switzerland           101.1  46.5                 74.9      109.1
# 2         Bahamas            85.0  36.7                 61.8       81.6
# 3         Iceland            83.0  39.2                 62.0       88.4
# 4       Singapore            76.7  67.2                 72.1       74.6
# 5        Barbados            76.6  19.0                 48.9       80.8
#
#       Restaurant Price  Local Purchasing Power
# Rank
# 1                 97.0                   158.7
# 2                 83.3                    54.6
# 3                 86.8                   120.3
# 4                 50.4                   111.1
# 5                 69.4                    43.5

# %%
plt.figure(figsize=(30,20))
plt.bar(data['Country'],data['Restaurant Price'])
plt.title('Restaurant Price per Countries')
plt.xlabel('Country')
plt.ylabel('Restaurant Price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,20))
plt.plot(data['Country'],data['Restaurant Price'])
plt.title('Restaurant Price per Countries')
plt.xlabel('Country')
plt.ylabel('Restaurant Price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,20))
plt.scatter(data['Country'],data['Restaurant Price'])
plt.title('Restaurant Price per Countries')
plt.xlabel('Country')
plt.ylabel('Restaurant Price')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
scatter_matrix(data, figsize=(20, 20), diagonal='kde',color='Maroon')

plt.suptitle('Scatter Matrix of All Numerical Columns')
plt.show()

# %%
data.head()
# Out:
#           Country  Cost of Living Index  Rent Index  \
# Rank
# 1     Switzerland                 101.1        46.5
# 2         Bahamas                  85.0        36.7
# 3         Iceland                  83.0        39.2
# 4       Singapore                  76.7        67.2
# 5        Barbados                  76.6        19.0
#
#       Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# Rank
# 1                               74.9            109.1                    97.0
# 2                               61.8             81.6                    83.3
# 3                               62.0             88.4                    86.8
# 4                               72.1             74.6                    50.4
# 5                               48.9             80.8                    69.4
#
#       Local Purchasing Power Index
# Rank
# 1                            158.7
# 2                             54.6
# 3                            120.3
# ...

# %%
#filtered_Data =data.loc[('')]
#filtered_Data.head()

# %%
#create boxplot
sns.boxplot(data=data)
plt.xticks(rotation=90)
#shoe the plot
plt.show()

# %%
data.columns
# Out:
# Index(['Country', 'Cost of Living', 'Rent', 'Sum of Rent and COL', 'Groceries',
#        'Restaurant Price', 'Local Purchasing Power'],
#       dtype='object')

# %%
variables=['Country', 'Cost of Living', 'Rent', 'Sum of Rent and COL', 'Groceries',
       'Restaurant Price', 'Local Purchasing Power']

# %%
plt.figure(figsize=(15,10))
for i,var in enumerate(variables,start=1):
    plt.subplot(4,3,i)
    sns.histplot(data[var], bins=20, kde=True, color='blue')
    kde_kws={'color': 'blue'}
    plt.title(f'histogram of {var}' )
    plt.xlabel(var)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.xticks(rotation=90)
plt.show()
